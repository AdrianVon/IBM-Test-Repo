# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Adrian Von Catangal**
#
# Machine Learning Engineer/Data Scientist

# %% [markdown]
# *I am interested in learning Data Science because I believe that combining data with intution is the best way to make decisions. By learning these principle I would hopefully be able to make to help make a positive impact on the world.*

# %% [markdown]
# ### My code below will print out the square root of 9.

# %%
print(int(9**.5))
# Out:
# 3

# %% [markdown]
# -----
#
# My favorite youtube video:
# https://www.youtube.com/watch?v=dQw4w9WgXcQ
#
# ![image.png](attachment:d63b02a2-b60f-41c9-aab0-3646b364ba6b.png)
#
# Image:Rick
#
# -----
#
# |Coursera Learning Path| + Other Learning Path|
# |-----|-----|
# |1. IBM Data Science Professional Certificate |1. Harvard's CS50 Intro to Python|
# |2. IBM Machine Learning |2. Harvard's CS50 Intro to Machine Learning with Python
# |3. Machine Learning |3. DataCamp's Data Science Career Certificate|
